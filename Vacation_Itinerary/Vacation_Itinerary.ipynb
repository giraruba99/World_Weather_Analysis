# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key = g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_hotel_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_hotel_df.head(50)
# Out:
#     City_ID             City Country  Max Temp   Current Description      Lat  \
# 0         0          Kahului      US     76.84            few clouds  20.8947
# 1         1   Port Elizabeth      ZA     67.10      scattered clouds -33.9180
# 2         2           Atuona      PF     78.01      scattered clouds  -9.8000
# 3         3            Ginir      ET     62.20         broken clouds   7.1333
# 4         6       Bredasdorp      ZA     64.27       overcast clouds -34.5322
# 5         7            Vaini      TO     69.96      scattered clouds -21.2000
# 6         9         Klaksvik      FO     43.72         broken clouds  62.2266
# 7        10  Arraial Do Cabo      BR     69.30             clear sky -22.9661
# 8        11      Yellowknife      CA     37.42             clear sky  62.4560
# 9        12          Marsala      IT     72.00       overcast clouds  37.7966
# 10       13          Ushuaia      AR     49.66      scattered clouds -54.8000
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# 3a. Get the data from each row and add it to the formatting template and store the data in a list.

hotel_info = [info_box_template.format(**row) for index, row in vacation_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.

locations = vacation_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

locations = vacation_hotel_df[["Lat", "Lng"]]
max_temp = vacation_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_hotel_df.loc[vacation_hotel_df["City"] == "Steamboat Springs"]
vacation_end = vacation_hotel_df.loc[vacation_hotel_df["City"] == "Steamboat Springs"]
vacation_stop1 = vacation_hotel_df.loc[vacation_hotel_df["City"] == "Bismarck"]
vacation_stop2 = vacation_hotel_df.loc[vacation_hotel_df["City"] == "Michigan City"] 
vacation_stop3 = vacation_hotel_df.loc[vacation_hotel_df["City"] == "Fortuna Foothills"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start['Lat'].values[0], vacation_start['Lng'].values[0]
end = vacation_end['Lat'].values[0], vacation_end['Lng'].values[0]
stop1 = vacation_stop1['Lat'].values[0], vacation_stop1['Lng'].values[0]
stop2 = vacation_stop2['Lat'].values[0], vacation_stop2['Lng'].values[0]
stop3 = vacation_stop3['Lat'].values[0], vacation_stop3['Lng'].values[0]

# %%
print(start)
print(stop1)
print(stop2)
print(stop3)
# Out:
# (40.485, -106.8317)
# (46.8083, -100.7837)
# (41.7075, -86.895)
# (32.6578, -114.4119)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be: 

# "DRIVING"

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
    start,end,waypoints=[stop1,stop2,stop3],
    travel_mode = "DRIVING"
)
fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be: 

# "BICYCLING",

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
    start,end,waypoints=[stop1,stop2,stop3],
    travel_mode = "BICYCLING"
)
fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be:

# "WALKING".

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
    start,end,waypoints=[stop1,stop2,stop3],
    travel_mode= "WALKING"
)
fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID               City Country  Max Temp Current Description      Lat  \
# 0      439  Steamboat Springs      US     53.10           clear sky  40.4850
# 1      439  Steamboat Springs      US     53.10           clear sky  40.4850
# 2      328           Bismarck      US     46.20     overcast clouds  46.8083
# 3      486      Michigan City      US     50.41     overcast clouds  41.7075
# 4      403  Fortuna Foothills      US     75.22           clear sky  32.6578
#
#         Lng                                      Hotel Name
# 0 -106.8317                                 Steamboat Grand
# 1 -106.8317                                 Steamboat Grand
# 2 -100.7837               Ramkota Hotel & Conference Center
# 3  -86.8950  Microtel Inn & Suites by Wyndham Michigan City
# 4 -114.4119                          Fortuna De Oro RV Park

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)


# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
